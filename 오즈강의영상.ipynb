# %%
# 주석은 이렇게 하는거다
print("진짜 안보이는거야?")
# print("신기하네")
# Out:
# 진짜 안보이는거야?

# %%
#""" """

# print("진짜 안보이는거야?")
# print("신기하네")
print("신기루")
# Out:
# 신기루

# %%
for 동물 in ("토끼","사자","푸바오","호랑이"):
    print(동물)
    print("보러 갈래요?")
# Out:
# 토끼
# 보러 갈래요?
# 사자
# 보러 갈래요?
# 푸바오
# 보러 갈래요?
# 호랑이
# 보러 갈래요?

# %%
for 동물 in ("토끼","사자","푸바오","호랑이"):
    print(동물)
print("보러 갈래요?")
# Out:
# 토끼
# 사자
# 푸바오
# 호랑이
# 보러 갈래요?

# %% [markdown]
# ###사칙연산
# 더하기 : +
#
# 뺴기 ; -
#
# 곱하기 : *
#
# 나누기 :
# *   / : 우리가 알고 있는 나누기와 동일한 기능(예 5/2 = 2.5)
# *   // : 몫을 반환 (예 5/2 2)
# *   % : 나머지를 반환 (예 5/2 1)
#
# 거듭제곱 : **

# %%
#더하기
print(3+2)
print(3+0)
# Out:
# 5
# 3

# %%
#
print(3+2,4-3,(9//3),4)
# Out:
# 5 1 3 4

# %%
#뺴기
print(3-1)
print(5-0)
# Out:
# 2
# 5

# %%
#곱하기
print(3*2)
print(5*0)
print(0*5)
# Out:
# 6
# 0
# 0

# %%
12*3
# Out:
# 36

# %%
#나누기
#/
print(7/2)

#//
print(7//2)

#%
print(7%2)
# Out:
# 3.5
# 3
# 1

# %% [markdown]
# 내장함수 : divmod
#
# >내장함수 : 자주 사용하는 기능을 ㄹ미리 만들어 놓은것을 내장함수라고 함
#
# **divmod** : 목과 나머지를 동시에 구해줌

# %%
print(divmod(3,2))
print(divmod(7,4))
print(divmod(15,3))
print(divmod(15,3))
print(7//4, ".",7%4)
# print(divmod(5,0)) # Removed the line causing division by zero error
# Out:
# (1, 1)
# (1, 3)
# (5, 0)
# (5, 0)
# 1 . 3

# %% [markdown]
# ### 괄호
#
# 수학에서 사용되는 괄호와 동일한 기능
# () : 괄호안에 있는 걸을 먼저 계산
# 사칙영ㄴ산 순서 : 괄호 -> 곱셈, 나눗셈 ->덧셈, 뺼셈

# %%
3+2*4
# Out:
# 11

# %%
(3+2)*4
# Out:
# 20

# %%
# 아아 : 5000원 / 아샷추 : 6500원
# 아아 2잔 /아샷추 3잔

(5000*2)+(6500*3)
# Out:
# 29500

# %%
# 미안한다 어제 아아 2잔 아샷추 3잔 금액 얼마였지?
(5000*2)+(6500*3)
# Out:
# 29500

# %% [markdown]
# ### 변수란? (기본중에 기본, 근본중에 근본, 고어중에 코어...)

# %%
# 변수를 사용할 떄
# 이전에 계산된 결과를 저장해서 사용할수 있다

sum = 1+2
sum = sum+3
sum = sum+4
sum = sum+5

print(sum)

sum2 = 1+2
sum2 += 3
sum2 += 4
sum2 += 5

print(sum2)
# Out:
# 15
# 15

# %%
# 주의!! 선언되지 않은 변수를 사용할 경우 에러 발생

sum3 = 0
sum3 += 1

sum3
# Out:
# 1

# %%
# 변수에 어떤값도 넣고 싶지 않고 선언하는 방법

nothing = None
print(None)
# Out:
# None

# %%
from sre_constants import BIGCHARSET
# 대소문자를 구분하는 변수
BIG = "크다"
big = "작다"

print(BIG,big)
# Out:
# 크다 작다

# %%
# 우리는 변수를 만들떄 스테이크케이스로 진행합니다. 그리고 언더바는 2개를 적용시켜주세요
# 개발에 관련된 여러 조건을 명시하는 건들을 코드 컨벤션이라고 합니다.

box__shose = "스니커즈"
box__hat = "슈프림 모자"

print(box__shose)
print(box__hat)
# Out:
# 스니커즈
# 슈프림 모자
